# %%
print("hola!9")
# Out:
# Running cells with 'Python 3.11.9' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/MaxPincher/AppData/Local/Microsoft/WindowsApps/python3.11.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ##### Esta es la clase de python
# * variables
# * operadores matemáticos basicos
# * operadores de comparacion
# * condicionales
#   - simples
#   - anidados
#   - encadenados
#
# * Estructura de datos
#   - listas
#   - cadenas de caracteres
#   - diccionarios
#   - tuplas
#
# * Estructuras de control
#   - funciones
#   - ciclos finitos
#   - ciclos infinitos
